# 2026-01-21 00:00:00-05:00  452.690002  438.679993  444.109985  37980500
# 2026-01-22 00:00:00-05:00  452.839996  444.700012  451.140015  25349400
# 2026-01-23 00:00:00-05:00  471.100006  450.529999  465.950012  38000200
#
#                            Dividends  Stock Splits
# Date
# 2026-01-16 00:00:00-05:00        0.0           0.0
# 2026-01-20 00:00:00-05:00        0.0           0.0
# 2026-01-21 00:00:00-05:00        0.0           0.0
# 2026-01-22 00:00:00-05:00        0.0           0.0
# 2026-01-23 00:00:00-05:00        0.0           0.0

# %%
hist.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-01-16 00:00:00-05:00  257.658902  258.657967  254.691677  255.291122
# 2026-01-20 00:00:00-05:00  252.493737  254.551809  243.192443  246.469376
# 2026-01-21 00:00:00-05:00  248.467509  251.324836  244.950795  247.418488
# 2026-01-22 00:00:00-05:00  248.967040  250.765360  247.918018  248.117844
# 2026-01-23 00:00:00-05:00  247.088808  249.176850  244.451261  247.808121
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-01-16 00:00:00-05:00  72142800        0.0           0.0
# 2026-01-20 00:00:00-05:00  80267500        0.0           0.0
# 2026-01-21 00:00:00-05:00  54641700        0.0           0.0
# 2026-01-22 00:00:00-05:00  39708300        0.0           0.0
# 2026-01-23 00:00:00-05:00  41689000        0.0           0.0

# %%
hist.index
# Out:
# DatetimeIndex(['2026-01-16 00:00:00-05:00', '2026-01-20 00:00:00-05:00',
#                '2026-01-21 00:00:00-05:00', '2026-01-22 00:00:00-05:00',
#                '2026-01-23 00:00:00-05:00', '2026-01-26 00:00:00-05:00',
#                '2026-01-27 00:00:00-05:00', '2026-01-28 00:00:00-05:00',
#                '2026-01-29 00:00:00-05:00', '2026-01-30 00:00:00-05:00',
#                '2026-02-02 00:00:00-05:00', '2026-02-03 00:00:00-05:00',
#                '2026-02-04 00:00:00-05:00', '2026-02-05 00:00:00-05:00',
#                '2026-02-06 00:00:00-05:00', '2026-02-09 00:00:00-05:00',
#                '2026-02-10 00:00:00-05:00', '2026-02-11 00:00:00-05:00',
#                '2026-02-12 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', freq=None)

# %%
hist.index = hist.index.strftime('%d %B %Y')

# %%
hist.head()
# Out:
#                        Open        High         Low       Close    Volume  \
# Date
# 16 January 2026  257.658902  258.657967  254.691677  255.291122  72142800
# 20 January 2026  252.493737  254.551809  243.192443  246.469376  80267500
# 21 January 2026  248.467509  251.324836  244.950795  247.418488  54641700
# 22 January 2026  248.967040  250.765360  247.918018  248.117844  39708300
# 23 January 2026  247.088808  249.176850  244.451261  247.808121  41689000
#
#                  Dividends  Stock Splits
# Date
# 16 January 2026        0.0           0.0
# 20 January 2026        0.0           0.0
# 21 January 2026        0.0           0.0
# 22 January 2026        0.0           0.0
# 23 January 2026        0.0           0.0

# %%
hist = hist[['Close']]
hist.columns = ['apple']
hist.head()
# Out:
#                       apple
# Date
# 16 January 2026  255.291122
# 20 January 2026  246.469376
# 21 January 2026  247.418488
# 22 January 2026  248.117844
# 23 January 2026  247.808121

# %%
hist =hist.T
hist
# Out:
# Date   16 January 2026  20 January 2026  21 January 2026  22 January 2026  \
# apple       255.291122       246.469376       247.418488       248.117844
#
# Date   23 January 2026  26 January 2026  27 January 2026  28 January 2026  \
# apple       247.808121       255.171234       258.028534       256.200287
#
# Date   29 January 2026  30 January 2026  02 February 2026  03 February 2026  \
# apple       258.038544       259.237427        269.757599        269.228088
#
# Date   04 February 2026  05 February 2026  06 February 2026  09 February 2026  \
# apple        276.231506        275.652069        277.859985        274.619995
#
# Date   10 February 2026  11 February 2026  12 February 2026
# apple        273.679993             275.5        261.730011

# %%
hist.index.name = 'Name'

# %%
hist
# Out:
# Date   16 January 2026  20 January 2026  21 January 2026  22 January 2026  \
# Name
# apple       255.291122       246.469376       247.418488       248.117844
#
# Date   23 January 2026  26 January 2026  27 January 2026  28 January 2026  \
# Name
# apple       247.808121       255.171234       258.028534       256.200287
#
# Date   29 January 2026  30 January 2026  02 February 2026  03 February 2026  \
# Name
# apple       258.038544       259.237427        269.757599        269.228088
#
# Date   04 February 2026  05 February 2026  06 February 2026  09 February 2026  \
# Name
# apple        276.231506        275.652069        277.859985        274.619995
#
# Date   10 February 2026  11 February 2026  12 February 2026
# Name
# apple        273.679993             275.5        261.730011

# %%
#ここまでの処理をまとめる
aapl=yf.Ticker('AAPL')
days = 20
hist = aapl.history(period = f'{days}d')
hist.index = hist.index.strftime('%d %B %Y')
hist = hist[['Close']]
hist.columns = ['apple']
hist =hist.T
hist.index.name = 'Name'
hist
# Out:
# Date   16 January 2026  20 January 2026  21 January 2026  22 January 2026  \
# Name
# apple       255.291122       246.469376       247.418488       248.117844
#
# Date   23 January 2026  26 January 2026  27 January 2026  28 January 2026  \
# Name
# apple       247.808121       255.171234       258.028534       256.200287
#
# Date   29 January 2026  30 January 2026  02 February 2026  03 February 2026  \
# Name
# apple       258.038544       259.237427        269.757599        269.228088
#
# Date   04 February 2026  05 February 2026  06 February 2026  09 February 2026  \
# Name
# apple        276.231506        275.652069        277.859985        274.619995
#
# Date   10 February 2026  11 February 2026  12 February 2026  13 February 2026
# Name
# apple        273.679993             275.5        261.730011        255.779999

# %%
#汎用化
def get_data(days,tickers):
    df = pd.DataFrame()
    for company in tickers.keys():
    #company = 'facebook'
        tkr = yf.Ticker(tickers[company])
        hist = tkr.history(period=f'{days}d')
        hist.index = hist.index.strftime('%d %B %Y')
        hist = hist[['Close']]
        hist.columns = [company]
        hist = hist.T
        hist.index.name = 'Name'
        df = pd.concat([df, hist])
    return df

# %%
days = 20
tickers = {
    'apple': 'AAPL',
    'facebook': 'FB',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN'
}
get_data(days, tickers)
# Out:
# Date       16 January 2026  20 January 2026  21 January 2026  22 January 2026  \
# Name
# apple           255.291122       246.469376       247.418488       248.117844
# facebook         42.506001        42.030998        42.230999        42.296001
# google          330.000000       322.000000       328.380005       330.540009
# microsoft       459.859985       454.519989       444.109985       451.140015
# netflix          88.000000        87.260002        85.360001        83.540001
# amazon          239.119995       231.000000       231.309998       234.339996
#
# Date       23 January 2026  26 January 2026  27 January 2026  28 January 2026  \
# Name
# apple           247.808121       255.171234       258.028534       256.200287
# facebook         42.324001        42.375999        42.380001        42.384998
# google          327.929993       333.260010       334.549988       336.010010
# microsoft       465.950012       470.279999       480.579987       481.630005
# netflix          86.120003        85.699997        85.580002        84.639999
# amazon          239.160004       238.419998       244.679993       243.009995
#
# Date       29 January 2026  30 January 2026  02 February 2026  \
# Name
# apple           258.038544       259.237427        269.757599
# facebook         42.330002        42.256001         42.262001
# google          338.250000       338.000000        343.690002
# microsoft       433.500000       430.290009        423.369995
# netflix          83.160004        83.489998         82.760002
# amazon          241.729996       239.300003        242.960007
#
# Date       03 February 2026  04 February 2026  05 February 2026  \
# Name
# apple            269.228088        276.231506        275.652069
# facebook          42.258999         42.153999         42.068001
# google           339.709991        333.040009        331.250000
# microsoft        411.209991        414.190002        393.670013
# netflix           79.940002         80.160004         80.870003
# amazon           238.619995        232.990005        222.690002
#
# Date       06 February 2026  09 February 2026  10 February 2026  \
# Name
# apple            277.859985        274.619995        273.679993
# facebook          42.419998         42.542000         42.540001
# google           322.859985        324.320007        318.579987
# microsoft        401.140015        413.600006        413.269989
# netflix           82.199997         81.470001         82.209999
# amazon           210.320007        208.720001        206.960007
#
# Date       11 February 2026  12 February 2026  13 February 2026
# Name
# apple            275.500000        261.730011        255.779999
# facebook          42.490002         42.283001         42.330002
# google           310.959991        309.000000        305.720001
# microsoft        404.369995        401.839996        401.320007
# netflix           79.620003         75.860001         76.870003
# amazon           204.080002        199.600006        198.789993

# %%
for company in tickers.keys():
    print(company)
# Out:
# apple
# facebook
# google
# microsoft
# netflix
# amazon

# %%
tickers.keys()
# Out:
# dict_keys(['apple', 'facebook'])

# %%
aapl = yf.Ticker('AAPL')
aapl.info #基本的な会社情報
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple Vision Pro, Apple TV, Apple Watch, Beats products, and HomePod, as well as Apple branded and third-party accessories. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV, which offers exclusive original content and live sports; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers and resellers. The company was formerly known as Apple Computer, Inc. and changed its name to Apple Inc. in January 2007. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 150000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 64,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2025,
#    'totalPay': 16759518,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevan  Parekh',
#    'age': 53,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2025,
#    'totalPay': 4034174,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Sabih  Khan',
#    'age': 58,
#    'title': 'Senior VP & Chief Operating Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2025,
#    'totalPay': 5021905,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 61,
#    'title': 'Senior VP, General Counsel & Secretary',
#    'yearBorn': 1964,
#    'fiscalYear': 2025,
#    'totalPay': 5022482,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 58,
#    'title': 'Senior Vice President of Retail & People',
#    'yearBorn': 1967,
#    'fiscalYear': 2025,
#    'totalPay': 5037867,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Ben  Borders',
#    'age': 44,
#    'title': 'Principal Accounting Officer',
#    'yearBorn': 1981,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kristin Huguet Quayle',
#    'title': 'Vice President of Worldwide Communications',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Adrian  Perica',
#    'age': 51,
#    'title': 'Vice President of Corporate Development',
#    'yearBorn': 1974,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 7,
#  'boardRisk': 1,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1769904000,
#  'compensationAsOfEpochDate': 1767139200,
#  'irWebsite': 'http://investor.apple.com/',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 261.73,
#  'open': 262.01,
#  'dayLow': 255.45,
#  'dayHigh': 262.23,
#  'regularMarketPreviousClose': 261.73,
#  'regularMarketOpen': 262.01,
#  'regularMarketDayLow': 255.45,
#  'regularMarketDayHigh': 262.23,
#  'dividendRate': 1.04,
#  'dividendYield': 0.41,
#  'exDividendDate': 1770595200,
#  'payoutRatio': 0.1304,
#  'fiveYearAvgDividendYield': 0.52,
#  'beta': 1.107,
#  'trailingPE': 32.377216,
#  'forwardPE': 27.538435,
#  'volume': 56134274,
#  'regularMarketVolume': 56134274,
#  'averageVolume': 48641162,
#  'averageVolume10days': 60052330,
#  'averageDailyVolume10Day': 60052330,
#  'bid': 243.75,
#  'ask': 255.74,
#  'bidSize': 1,
#  'askSize': 1,
#  'marketCap': 3759435415552,
#  'fiftyTwoWeekLow': 169.21,
#  'fiftyTwoWeekHigh': 288.62,
#  'allTimeHigh': 288.62,
#  'allTimeLow': 0.049107,
#  'priceToSalesTrailing12Months': 8.630139,
#  'fiftyDayAverage': 267.4752,
#  'twoHundredDayAverage': 240.0591,
#  'trailingAnnualDividendRate': 1.03,
#  'trailingAnnualDividendYield': 0.003935353,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 3778743894016,
#  'profitMargins': 0.27037,
#  'floatShares': 14655594816,
#  'sharesOutstanding': 14681140000,
#  'sharesShort': 116854414,
#  'sharesShortPriorMonth': 112732788,
#  'sharesShortPreviousMonthDate': 1767139200,
#  'dateShortInterest': 1769731200,
#  'sharesPercentSharesOut': 0.008,
#  'heldPercentInsiders': 0.017070001,
#  'heldPercentInstitutions': 0.65483004,
#  'shortRatio': 2.36,
#  'shortPercentOfFloat': 0.008,
#  'impliedSharesOutstanding': 14697926000,
#  'bookValue': 5.998,
#  'priceToBook': 42.644215,
#  'lastFiscalYearEnd': 1758931200,
#  'nextFiscalYearEnd': 1790467200,
#  'mostRecentQuarter': 1766793600,
#  'earningsQuarterlyGrowth': 0.159,
#  'netIncomeToCommon': 117776998400,
#  'trailingEps': 7.9,
#  'forwardEps': 9.28811,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 8.674,
#  'enterpriseToEbitda': 24.714,
#  '52WeekChange': 0.046263337,
#  'SandP52WeekChange': 0.11527538,
#  'lastDividendValue': 0.26,
#  'lastDividendDate': 1770595200,
#  'quoteType': 'EQUITY',
#  'currentPrice': 255.78,
#  'targetHighPrice': 350.0,
#  'targetLowPrice': 205.0,
#  'targetMeanPrice': 292.14624,
#  'targetMedianPrice': 300.0,
#  'recommendationMean': 1.95652,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 40,
#  'totalCash': 66907000832,
#  'totalCashPerShare': 4.557,
#  'ebitda': 152901992448,
#  'totalDebt': 90509000704,
#  'quickRatio': 0.845,
#  'currentRatio': 0.974,
#  'totalRevenue': 435617005568,
#  'debtToEquity': 102.63,
#  'revenuePerShare': 29.305,
#  'returnOnAssets': 0.24377,
#  'returnOnEquity': 1.5202099,
#  'grossProfits': 206157004800,
#  'freeCashflow': 106312753152,
#  'operatingCashflow': 135471996928,
#  'earningsGrowth': 0.183,
#  'revenueGrowth': 0.157,
#  'grossMargins': 0.47325,
#  'ebitdaMargins': 0.35099998,
#  'operatingMargins': 0.35374,
#  'financialCurrency': 'USD',
#  'symbol': 'AAPL',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'epsTrailingTwelveMonths': 7.9,
#  'epsForward': 9.28811,
#  'epsCurrentYear': 8.48542,
#  'priceEpsCurrentYear': 30.143469,
#  'fiftyDayAverageChange': -11.69519,
#  'fiftyDayAverageChangePercent': -0.043724395,
#  'twoHundredDayAverageChange': 15.7209015,
#  'twoHundredDayAverageChangePercent': 0.06548763,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '2.0 - Buy',
#  'cryptoTradeable': False,
#  'marketState': 'CLOSED',
#  'corporateActions': [],
#  'postMarketTime': 1771030799,
#  'regularMarketTime': 1771016402,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_24937',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 345479400000,
#  'postMarketChangePercent': -0.18746273,
#  'postMarketPrice': 255.3005,
#  'postMarketChange': -0.4794922,
#  'regularMarketChange': -5.95001,
#  'regularMarketDayRange': '255.45 - 262.23',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 48641162,
#  'fiftyTwoWeekLowChange': 86.56999,
#  'fiftyTwoWeekLowChangePercent': 0.5116127,
#  'fiftyTwoWeekRange': '169.21 - 288.62',
#  'fiftyTwoWeekHighChange': -32.839996,
#  'fiftyTwoWeekHighChangePercent': -0.113782816,
#  'fiftyTwoWeekChangePercent': 4.6263337,
#  'dividendDate': 1770854400,
#  'earningsTimestamp': 1769720400,
#  'earningsTimestampStart': 1777582800,
#  'earningsTimestampEnd': 1777582800,
#  'earningsCallTimestampStart': 1769724000,
#  'earningsCallTimestampEnd': 1769724000,
#  'isEarningsDateEstimate': True,
#  'regularMarketChangePercent': -2.27334,
#  'regularMarketPrice': 255.78,
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'displayName': 'Apple',
#  'trailingPegRatio': 2.3096}

# %%
aapl.actions.head()#配当金に関する情報
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-05-11 00:00:00-04:00   0.000536           0.0
# 1987-06-16 00:00:00-04:00   0.000000           2.0
# 1987-08-10 00:00:00-04:00   0.000536           0.0
# 1987-11-17 00:00:00-05:00   0.000714           0.0
# 1988-02-12 00:00:00-05:00   0.000714           0.0

# %%
aapl.dividends.plot() #配当金の可視化
# Out:
# <Axes: xlabel='Date'>

# %%
aapl.actions['Stock Splits'].plot() #分配の可視化
# Out:
# <Axes: xlabel='Date'>

# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in /Library/anaconda3/lib/python3.13/site-packages (5.5.0)
# Requirement already satisfied: jinja2 in /Library/anaconda3/lib/python3.13/site-packages (from altair) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /Library/anaconda3/lib/python3.13/site-packages (from altair) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in /Library/anaconda3/lib/python3.13/site-packages (from altair) (2.7.0)
# Requirement already satisfied: packaging in /Library/anaconda3/lib/python3.13/site-packages (from altair) (25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Library/anaconda3/lib/python3.13/site-packages (from altair) (4.15.0)
# Requirement already satisfied: attrs>=22.2.0 in /Library/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair) (0.28.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/anaconda3/lib/python3.13/site-packages (from jinja2->altair) (3.0.2)

# %% [markdown]
# # グラフかするためのデータ処理

# %%
import altair as alt

# %%
df = get_data(days, tickers)
df
# Out:
# Date       16 January 2026  20 January 2026  21 January 2026  22 January 2026  \
# Name
# apple           255.291122       246.469376       247.418488       248.117844
# facebook         42.506001        42.030998        42.230999        42.296001
# google          330.000000       322.000000       328.380005       330.540009
# microsoft       459.859985       454.519989       444.109985       451.140015
# netflix          88.000000        87.260002        85.360001        83.540001
# amazon          239.119995       231.000000       231.309998       234.339996
#
# Date       23 January 2026  26 January 2026  27 January 2026  28 January 2026  \
# Name
# apple           247.808121       255.171234       258.028534       256.200287
# facebook         42.324001        42.375999        42.380001        42.384998
# google          327.929993       333.260010       334.549988       336.010010
# microsoft       465.950012       470.279999       480.579987       481.630005
# netflix          86.120003        85.699997        85.580002        84.639999
# amazon          239.160004       238.419998       244.679993       243.009995
#
# Date       29 January 2026  30 January 2026  02 February 2026  \
# Name
# apple           258.038544       259.237427        269.757599
# facebook         42.330002        42.256001         42.262001
# google          338.250000       338.000000        343.690002
# microsoft       433.500000       430.290009        423.369995
# netflix          83.160004        83.489998         82.760002
# amazon          241.729996       239.300003        242.960007
#
# Date       03 February 2026  04 February 2026  05 February 2026  \
# Name
# apple            269.228088        276.231506        275.652069
# facebook          42.258999         42.153999         42.068001
# google           339.709991        333.040009        331.250000
# microsoft        411.209991        414.190002        393.670013
# netflix           79.940002         80.160004         80.870003
# amazon           238.619995        232.990005        222.690002
#
# Date       06 February 2026  09 February 2026  10 February 2026  \
# Name
# apple            277.859985        274.619995        273.679993
# facebook          42.419998         42.542000         42.540001
# google           322.859985        324.320007        318.579987
# microsoft        401.140015        413.600006        413.269989
# netflix           82.199997         81.470001         82.209999
# amazon           210.320007        208.720001        206.960007
#
# Date       11 February 2026  12 February 2026  13 February 2026
# Name
# apple            275.500000        261.730011        255.779999
# facebook          42.490002         42.283001         42.330002
# google           310.959991        309.000000        305.720001
# microsoft        404.369995        401.839996        401.320007
# netflix           79.620003         75.860001         76.870003
# amazon           204.080002        199.600006        198.789993

# %%
companies = ['apple', 'facebook']
data = df.loc[companies]
data
# Out:
# Date      16 January 2026  20 January 2026  21 January 2026  22 January 2026  \
# Name
# apple          255.291122       246.469376       247.418488       248.117844
# facebook        42.506001        42.030998        42.230999        42.296001
#
# Date      23 January 2026  26 January 2026  27 January 2026  28 January 2026  \
# Name
# apple          247.808121       255.171234       258.028534       256.200287
# facebook        42.324001        42.375999        42.380001        42.384998
#
# Date      29 January 2026  30 January 2026  02 February 2026  \
# Name
# apple          258.038544       259.237427        269.757599
# facebook        42.330002        42.256001         42.262001
#
# Date      03 February 2026  04 February 2026  05 February 2026  \
# Name
# apple           269.228088        276.231506        275.652069
# facebook         42.258999         42.153999         42.068001
#
# Date      06 February 2026  09 February 2026  10 February 2026  \
# Name
# apple           277.859985        274.619995        273.679993
# facebook         42.419998         42.542000         42.540001
#
# Date      11 February 2026  12 February 2026  13 February 2026
# Name
# apple           275.500000        261.730011        255.779999
# facebook         42.490002         42.283001         42.330002

# %%
data = data.T.reset_index()
data
# Out:
# Name              Date       apple   facebook
# 0      16 January 2026  255.291122  42.506001
# 1      20 January 2026  246.469376  42.030998
# 2      21 January 2026  247.418488  42.230999
# 3      22 January 2026  248.117844  42.296001
# 4      23 January 2026  247.808121  42.324001
# 5      26 January 2026  255.171234  42.375999
# 6      27 January 2026  258.028534  42.380001
# 7      28 January 2026  256.200287  42.384998
# 8      29 January 2026  258.038544  42.330002
# 9      30 January 2026  259.237427  42.256001
# 10    02 February 2026  269.757599  42.262001
# 11    03 February 2026  269.228088  42.258999
# 12    04 February 2026  276.231506  42.153999
# 13    05 February 2026  275.652069  42.068001
# 14    06 February 2026  277.859985  42.419998
# 15    09 February 2026  274.619995  42.542000
# 16    10 February 2026  273.679993  42.540001
# 17    11 February 2026  275.500000  42.490002
# 18    12 February 2026  261.730011  42.283001
# 19    13 February 2026  255.779999  42.330002

# %%
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices(USD)'}
)
data
# Out:
#                 Date      Name  Stock Prices(USD)
# 0    16 January 2026     apple         255.291122
# 1    20 January 2026     apple         246.469376
# 2    21 January 2026     apple         247.418488
# 3    22 January 2026     apple         248.117844
# 4    23 January 2026     apple         247.808121
# 5    26 January 2026     apple         255.171234
# 6    27 January 2026     apple         258.028534
# 7    28 January 2026     apple         256.200287
# 8    29 January 2026     apple         258.038544
# 9    30 January 2026     apple         259.237427
# 10  02 February 2026     apple         269.757599
# 11  03 February 2026     apple         269.228088
# 12  04 February 2026     apple         276.231506
# 13  05 February 2026     apple         275.652069
# 14  06 February 2026     apple         277.859985
# 15  09 February 2026     apple         274.619995
# 16  10 February 2026     apple         273.679993
# 17  11 February 2026     apple         275.500000
# 18  12 February 2026     apple         261.730011
# 19  13 February 2026     apple         255.779999
# 20   16 January 2026  facebook          42.506001
# 21   20 January 2026  facebook          42.030998
# 22   21 January 2026  facebook          42.230999
# 23   22 January 2026  facebook          42.296001
# 24   23 January 2026  facebook          42.324001
# 25   26 January 2026  facebook          42.375999
# 26   27 January 2026  facebook          42.380001
# 27   28 January 2026  facebook          42.384998
# 28   29 January 2026  facebook          42.330002
# 29   30 January 2026  facebook          42.256001
# 30  02 February 2026  facebook          42.262001
# 31  03 February 2026  facebook          42.258999
# 32  04 February 2026  facebook          42.153999
# 33  05 February 2026  facebook          42.068001
# 34  06 February 2026  facebook          42.419998
# 35  09 February 2026  facebook          42.542000
# 36  10 February 2026  facebook          42.540001
# 37  11 February 2026  facebook          42.490002
# 38  12 February 2026  facebook          42.283001
# 39  13 February 2026  facebook          42.330002

# %%
ymin, ymax = 250, 300

chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x = "Date:T",
        y = alt.Y("Stock Prices(USD)", stack=None, scale=alt.Scale(domain=[ymin, ymax])),
        color = 'Name:N' 
    )
)

# %%
chart
# Out:
# alt.Chart(...)
